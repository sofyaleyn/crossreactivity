# %% [markdown]
# # CrossFlag anchor validation (SHR-1210 -> VEGFR2)
#
# STUB. Demos the full evidence ladder on the SHR-1210 anchor (HANDOFF Step 12).
# Beats defined in [docs/demo-run.md](../docs/demo-run.md):
#
# 1. **Beat 1** - WT SHR-1210 flags VEGFR2/FZD5/ULBP2 from the reference set (embedding rank).
# 2. **Beat 2** - panel ranking: WT dropped, germlined mutants advanced.
# 3. **Beat 3** - Boltz-2 cofold: WT docks VEGFR2, germlined mutant interface collapses.
#
# Fill in once `crossflag.pipeline` and the confirmation ladder are implemented.
